# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
print("Trignometric calculator")
print("========================")

answer=["sin",'cos','tan','cot','coses','sec']
for i in answer:
    print('-',i)
user_input=input("Which function do u want to perform  : ").title()
angle=float(input("Enter a angle: "))
if user_input=='Sin':
    sin=np.sin(angle)
    print(f"{user_input}{angle} is {sin}")
elif user_input=='Cos':
    cos=np.cos(angle)
    print(f"{user_input}{angle} is {cos}")
elif user_input=='Tan':
    tan=np.tan(angle)
    print(f"{user_input}{angle} is {tan}")
elif user_input=='Cosec':
    cosec1=np.sin(angle)
    cosec=1/cosec1
    print(f"{user_input}{angle} is {cosec}")
    
elif user_input=='Sec':
    sec1=np.cos(angle)
    sec=1/cos
    print(f"{user_input}{angle} is {sec}")
    
elif user_input=='Cot':
    tan=np.tan(angle)
    cot=1/tan
    print(f"{user_input}{angle} is {cot}")
# Out:
# Trignometric calculator
# ...
# - sin
# - cos
# - tan
# - cot
# - coses
# - sec
# Which function do u want to perform  : sin
# Enter a angle: 20
# Sin20.0 is 0.9129452507276277

# %% [markdown]
# # Graph...

# %%
angle=float(input("Enter a angle:  up to range value 0-5"))
x_sin=np.arange(angle,2*np.pi,0.4)
print(x_sin)
# Out:
# Enter a angle:  up to range value 0-52
# [2.  2.4 2.8 3.2 3.6 4.  4.4 4.8 5.2 5.6 6. ]

# %%
y_sin=np.sin(x_sin)
# print(y_sin)

# %%
plt.plot(x_sin,y_sin)
plt.show()

# %%
y_cos=np.cos(x_sin)
print(y_cos)
# Out:
# [-0.41614684 -0.73739372 -0.94222234 -0.99829478 -0.89675842 -0.65364362
#  -0.30733287  0.08749898  0.46851667  0.77556588  0.96017029]

# %%
plt.plot(x_sin,y_cos)
plt.show()

# %%
y_tan=np.tan(x_sin)
print(y_tan)
# Out:
# [ -2.18503986  -0.91601429  -0.35552983   0.05847385   0.49346673
#    1.15782128   3.09632378 -11.38487065  -1.88564188  -0.81394328
#   -0.29100619]

# %%
plt.plot(x_sin,y_tan)
plt.show()
